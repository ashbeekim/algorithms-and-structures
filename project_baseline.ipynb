# %% [markdown]
# <a href="https://colab.research.google.com/github/AshbeeKim/BAEKJOON/blob/main/project_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 아이디어 to 비즈니스
#
# * 탐색&테스트
#  * 발견
#  * 검증
# * 실행
# * 비즈니스 콘셉트 디자인(아이디어+비즈니스 모델+가치 제안)=>수익성 확보
# * 테스트와 리스크 줄이기(핵심 가설+실험+핵심 통찰)
#  * 실현 가능성 리스크
#  * 수용 가능성 리스크
#  * 생존 가능성 리스크
#
# 1. 디자인
#  * 팀 디자인
#  * 아이디어 형성
# 2. 테스트
#  * 가설
#  * 실험
#  * 학습
#  * 결정
#  * 관리
# 3. 실험
#  * 실험 선택
#  * 발견
#  * 검증
# 4. 마인드셋
#  * 실험의 함정 피하기
#  * 실험을 통한 조직 이끌기
#  * 실험하는 조직 만들기

# %% [markdown]
# ### Reliable Open Data Sites
# * [World Bank Open Data] https://data.worldbank.org/
# * [WHO] https://www.who.int/data/gho/
# * [Google Public Data Explorer] https://www.google.com/publicdata/directory https://www.google.com/publicdata/directory?hl=en_US&dl=en_US#!
# * [Registry of Open Data on AWS(RODA)] https://registry.opendata.aws/
# * [European Union Open Data Portal] https://data.europa.eu/data/datasets?locale=en&minScoring=0
# * [FiveThirtyEight] https://data.fivethirtyeight.com/
# * [U.S. Census Bureau] https://www.census.gov/data.html
# * [Data.gov] https://www.data.gov/
# * [DBpedia] https://www.dbpedia.org/
# * [freeCodeCamp Open Data] https://github.com/freeCodeCamp/open-data
# * [Yelp Open Datasets] https://www.yelp.com/dataset
# * [UNICEF Dataset] https://data.unicef.org/
# * [Kaggle] https://www.kaggle.com/datasets
# * [LODUM] https://www.uni-muenster.de/LODUM/
# * [UCI Machine Learning Repository] https://archive.ics.uci.edu/ml/index.php
#
#
#
# ```
# # [ref] https://www.freecodecamp.org/news/https-medium-freecodecamp-org-best-free-open-data-sources-anyone-can-use-a65b514b0f2d/
# ```

# %%
import os

from google.colab import drive  
ROOT = "/content/drive"
drive.mount(ROOT)

from os.path import join  
MY_GOOGLE_DRIVE_PATH = "MyDrive/Task"
PROJECT = "Proj_AnyRoad"
PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH, PROJECT) #os.path.join은 자동으로 '/'생성

# !mkdir "{PROJECT_PATH}"
# print(PROJECT_PATH)

# %cd "{PROJECT_PATH}"

# %%
import sys
import time
import math

import csv
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.core.display import display, HTML

import requests as rqst
from bs4 import BeautifulSoup as bs

from selenium import webdriver
from urllib.request import urlopen
from urllib.parse import quote_plus
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# <img src="https://github.com/nestauk/im-tutorials/blob/3-ysi-tutorial/figures/Web-Scraping/dom_tree.gif?raw=1" alt="image by 'https://colab.research.google.com/github/nestauk/im-tutorials/blob/3-ysi-tutorial/notebooks/Web-Scraping/Web%20Scraping%20Tutorial.ipynb#scrollTo=PBy52pAixqhD's owner"/>
#
# <img src="https://github.com/nestauk/im-tutorials/blob/3-ysi-tutorial/figures/Web-Scraping/scrape-pipeline.png?raw=1" alt="image by 'https://colab.research.google.com/github/nestauk/im-tutorials/blob/3-ysi-tutorial/notebooks/Web-Scraping/Web%20Scraping%20Tutorial.ipynb#scrollTo=PBy52pAixqhD's owner"/>
#
# <img src="https://github.com/nestauk/im-tutorials/blob/3-ysi-tutorial/figures/Web-Scraping/boxofficemojo-pipeline.png?raw=1" alt="image by 'https://colab.research.google.com/github/nestauk/im-tutorials/blob/3-ysi-tutorial/notebooks/Web-Scraping/Web%20Scraping%20Tutorial.ipynb#scrollTo=PBy52pAixqhD's owner"/>
#
# <img src="https://github.com/nestauk/im-tutorials/blob/3-ysi-tutorial/figures/Web-Scraping/selenium-pipeline.png?raw=1" alt="image by 'https://colab.research.google.com/github/nestauk/im-tutorials/blob/3-ysi-tutorial/notebooks/Web-Scraping/Web%20Scraping%20Tutorial.ipynb#scrollTo=PBy52pAixqhD's owner"/>
#
#
#
# <img src="https://github.com/nestauk/im-tutorials/blob/3-ysi-tutorial/figures/Web-Scraping/robots.png?raw=1" alt="image by 'https://colab.research.google.com/github/nestauk/im-tutorials/blob/3-ysi-tutorial/notebooks/Web-Scraping/Web%20Scraping%20Tutorial.ipynb#scrollTo=PBy52pAixqhD's owner"/>
#
# #### Additional resources/references:
#
# * [Document Object Model (DOM)](https://developer.mozilla.org/en-US/docs/Web/API/Document_Object_Model/Introduction)
# * [HTML elements reference guide](https://www.w3schools.com/tags/default.asp)
# * [About /robots.txt](https://www.robotstxt.org/robotstxt.html)
# * [The robots.txt file](https://varvy.com/robottxt.html)
# * [Ethics in Web Scraping](https://towardsdatascience.com/ethics-in-web-scraping-b96b18136f01)
# * [On the Ethics of Web Scraping](http://robertorocha.info/on-the-ethics-of-web-scraping/)
# * [User-Agent](https://en.wikipedia.org/wiki/User_agent)
# * [BeautifulSoup documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# * [Selinium Python - Unofficial documentation](https://selenium-python.readthedocs.io/)
# * [ARGUS paper](http://ftp.zew.de/pub/zew-docs/dp/dp18033.pdf)
# * [Brian's C. Keegan](http://www.brianckeegan.com/) excellent [5-week web scraping course](https://github.com/CU-ITSS/Web-Data-Scraping-S2019) intended for researchers in the social sciences and humanities.

# %% [markdown]
# ### referances
#
# 1. www.un.org/Depts/unsd
# UN(United Nations)
# 전 세계 인구, 사회지표, 경제, 환경 관련통계.
#
# 2. www.wto.org
# WTO(World Trade Organization)
# 전 세계 무역통계 (지역별, 분야별) 제공.
#
# 3. www.worldbank.org
# World Bank
# 인구, 환경, 주요경제지표, 무역과 재정 관련 주요지표 제공
#
# 4. www.imf.org
# International Monetary Fund
# 재정관련 통계
#
# 5. www.unece.org/stats/<wbr />stats_h.htm
# ECE
# UN/ECE 통계 홈페이지. 날짜별, 코드별, 주제별 통계자료 제공.
#
# 6. www.fao.org
# FAO
# 농, 수, 임업 등에 대한 통계 DB제공
#
# 7. www.asidnet.org
# ASID
# 아시안 10개국의 6천여 기업정보 데이터베이스 제공.
#
# 8. www.oecd.org
# OECD Statistics
# OECD가 운영하는 통계사이트.
# 개발지원위원회, 경제, 교육, 에너지, 환경, 금융, 공공부문 및 과학기술, 사회정책 등에 관한 데이터 제공
#
# 9. www.libraries.psu.edu
# Guide to International Statistics(Penn State University Libraries)
# LEXIS-NEXIS로 부터 각 분야별 통계, 국제 통계 index. 세계 각국의 주요 통계요약,
# 데이터 설치를 위한 web-site. 역사적 통계정보 제공.
#
# 10. www.un.org/Depts/unsd
# UN-Statistics Division-Machine readable products
# 국제 평화와 안전기구, 경제·사회개발, 인권, 국제법. UN통계업무부서의 홈페이지로 상품거래,
# 국민계정, 인구, 사회지표, 산업, 에너지, 환경 등에 관한 통계 및 통계조사방법 제공
#
# 11. www.adb.org
# Asian Development Bank
# 아시아 개발은행 홈페이지. 통계와 금융정보 제공.
#
# 12. www.kostat.go.kr
# 통계정보시스템
# 한국 통계청 홈페이지. 국토, 기후, 국민계정, 산업, 재정, 무역 등 전 분야 통계자료 제공. 한글과 영문 제공.
#
# 13. www.bps.go.id
# BPS, Central Bureau of Statistics, Rep.of INDONESIA
# 인도네시아 통계청 홈페이지. 인구, 농업, 경제 통계 제공.
#
# 14. www.dsec.gov.mo
# Business China-Facts & Figures
# 마카오 해외무역통계 제공.
#
# 15. www.chinaonline.com/refer/<wbr />statistics/secure/<wbr />statistics.asp
# China-Statistics
# 중국경제의 통계 tables과 무역 관련 통계 data 제공.
#
# 16. www.ncti-india.com
# ADEX-Estadisticas(statistical information on tariff, product and country)
# 인도 무역진흥기구와 국가정보센터가 설립한 비영리 단체. 인도 통계와 국가정보 제공.
#
# 17. www.statistics.gov.my
# Department of Statistics
# 말레이시아 통계청 홈페이지. 최근update된 통계정보 제공, keyword 선택 검색.
#
# 18. www.nscb.gov.ph
# National Statistical Coordination Board
# 필리핀 국가통계 Coordination Board 지역별, 각 분야별 통계 제공.
#
# 19. www.stats.govt.nz
# Statistics New Zealand
# 뉴질랜드 중앙 통계청 홈페이지.
#
# 20. www.abs.gov.au
# ABS WWW Information Service(Australia)
# 호주 통계청 홈페이지. 세계경제, 산업, 인구 등 통계정보 제공.
#
# 21. http://www.statistics.gov.uk/
# CCTA Government Information Service(영국)
# UK 정부관련 모든 정보. 통계도 제공
#
# 22. www.bundesbank.de
# Deutsche Bundesbank
# 독일연방공화국의 중앙은행 홈페이지. 최신 통계정보 제공.
#
# 23. www.destatis.de
# Federal Statistical Office : statistics.
# 독일 연방정부 통계청 홈페이지.
#
# 24. www.hgk.hr
# Croatian Chamber of Economy
# 크로아티아 통계서비스. 주요 인구, 산업, 경제, 무역, 환경관련 통계. 인구센서스.
#
# 25. www.gzs.si
# Economic Movements-Slovenia
# 슬로베니아에 관한 기초 정보 제공(위치, 정치적 상황, 크기, 언어, 여행지, 날씨 등) 사업기회 제공.
#
# 26. www.1182.ee
# ESTONIAN ECONOMY-facts and figures
# 에스토니아 주요 경제지표 검색 가능
#
# 27. www.foreigntrade.gov.tr
# Foreign trade Staistics-Turkey
# 터키 해외무역통계 제공
#
# 28. www.statistik.admin.ch
# Swiss Federal Statistical Office
# 스위스 통계청 홈페이지
#
# 29. www.statistics.gr
# National Statistical Service(그리스)
# 그리스 국가통계서비스 홈페이지, 나라별, 지역별 통계 데이타 제공.
# 인구센서스, 노동, 무역, 운송, 소비자물가 등 통계자료 검색 가능
#
# 30. www.die.gov.tr/ENGLISH/<wbr />index.html
# State Institute of Statistics(SIS)-Turkey
# 터키의 통계연구소 홈페이지. 터키의 사회, 경제, 문화, 주제별 데이트제공 (단, 사이트 내용열람 불가)
#
# 31. www.venexport.com/index.htm
# Venezuela Industry Directory
# 베네주엘라 산업별 통계
#
# 32. www.abs.gov.au
# Austrialian Bureau of Statistics
# 호주 통계청 홈페이지
#
# 33. www.ined.fr
# Statistics France
# 프랑스 통계청 홈페이지
#
# 34. www.statice.is
# Statistics Iceland
# 아이슬랜드 국가 통계청. 경제, 노동, 사회문제에 대한 통계. 17c~1990까지
# 아이슬랜드 역사적 통계제공(출판물)
#
# 35. www.istat.it
# Statistics Italy
# 이탈리아 국가 통계청.
#
# 36. www.ssb.no
# Statistics Norway
# 노르웨이 통계청 홈페이지
#
# 37. www.scb.se
# Statistics Sweden
# 스웨덴 통계청 홈페이지
#
# 38. www.ine.es
# Statistics Spain
# 스페인 국가 통계청 홈페이지 인구통계, 사회, 경제, 농업, 산업 등 최신 통계 제공
#
# 39. www.dst.dk
# Statistics Denmark
# 덴마크 통계청 홈페이지. 인구, 산업, 환경, 경제 관련 통계 제공
#
# 40. www.statcan.ca/start.html
# Statistics Canada
# 캐나다 통계청 홈페이지, 최근경제지표(인구, 소비자 가격index, 실업률, 실제 총액, 국내물품)
#
# 41. www.fedstats.gov
# Federal Statistical Agencies in U.S(FDSTATS)(미국)
# 미국 연방통계청 홈페이지.
#
# 42. www.stat-usa.gov
# STAT-USA:NTDB and other d-bases(US Dept of Commerce)(pay)
# 미상무부 데이터베이스로 각종 무역통계 접속 가능
#
# 43. www.census.gov
# U.S.Census Bureau-Includes US HS 96 Imports(Acrobat needed)
# 미상무부 산하 Census Bureau 홈페이지.
# 미국경제와 인구에 관한 질 높은 Data 제공. 인구, 경제, 지리 등에 관한 센서스 자료.
#
# 44. www.usda.gov
# USDA-National Agricultural Statistics Service, Statistical Highlights
# 미국의 농림부. 미국의 농업에 관한 각종 통계 검색 가능
#
# 45. www.indec.mecon.ar
# Statistics Argentina
# 아르헨티나 통계청홈페이지
#
# 46. www.ibge.gov.br
# Brazilian Statistical and Geographic Foundation(IBGE)(브라질)
# 브라질 IBGE 홈페이지. 인구, 경제, 지구과학 등 통계정보
